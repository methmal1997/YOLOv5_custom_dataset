# %%
# %cd yolo_dir
# Out:
# /data/shared/methmal/PycharmProjects/YOLOv5_custom_dataset/yolo_dir

# %%
# !python detect.py --source test1.jpeg --weights runs/train/exp/weights/best.pt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=test1.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-8-27 Python-3.9.7 torch-1.12.0 CUDA:0 (GeForce RTX 2060 SUPER, 7982MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data/shared/methmal/PycharmProjects/YOLOv5_custom_dataset/yolo_dir/test1.jpeg: 480x640 1 Man, 6.8ms
# Speed: 0.2ms pre-process, 6.8ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/detect/exp/test1.jpeg', width=1000)
